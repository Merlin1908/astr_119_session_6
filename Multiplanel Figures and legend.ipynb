# %% [markdown]
# # Making multipanel plots with matplotlib
#
# first, we inport numpy and matplotlib as usual

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Then we define an array of angles, and their sines and cosines using numpy. This time we will use linspace

# %%
x = np.linspace(0,2*np.pi,100)
print(x[-1],2*np.pi)

y = np.sin(x)
z = np.cos(x)
w = np.sin(4*x)
v = np.cos(4*x)
# Out:
# 6.283185307179586 6.283185307179586

# %% [markdown]
# Now, let's make a two panel plot side-by-side

# %%
f, axarr = plt.subplots(1,2)

axarr[0].plot(x, y)
axarr[0].set_xlabel('x')
axarr[0].set_ylabel('sin(x)')
axarr[0].set_title(r'$\sin(x)$')

axarr[1].plot(x, z)
axarr[1].set_xlabel('x')
axarr[1].set_ylabel('cos(x)')
axarr[1].set_title(r'$\cos(x)$')

f.subplots_adjust(wspace=0.4)


axarr[0].set_aspect('equal')
axarr[1].set_aspect(np.pi)

# %% [markdown]
# ### Let's keep the figure, merge them, remove the titles and add legends

# %%
#adjust the size of the figure
fig = plt.figure(figsize=(6,6))


plt.plot(x, y, label=r'$y = \sin(x)$')
plt.plot(x, z, label=r'$y = \cos(x)$')
plt.plot(x, w, label=r'$y = \sin(4x)$')
plt.plot(x, v, label=r'$y = \cos(4x)$')

plt.xlabel(r'$x$')
plt.ylabel(r'$y(x)$')
plt.xlim([0,2*np.pi])
plt.ylim([-1.2,1.2])
plt.legend(lcc=1, framealpha=0.95)


plt.gca().set_aspect(np.pi/1.2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-9e2720822121> in <module>()
#      12 plt.xlim([0,2*np.pi])
#      13 plt.ylim([-1.2,1.2])
# ---> 14 plt.legend(lcc=1, framealpha=0.95)
#      15
#      16
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/pyplot.py in legend(*args, **kwargs)
#    2658 @docstring.copy_dedent(Axes.legend)
#    2659 def legend(*args, **kwargs):
# -> 2660     return gca().legend(*args, **kwargs)
#    2661
#    2662 # Autogenerated by boilerplate.py.  Do not edit as changes will be lost.
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/axes/_axes.py in legend(self, *args, **kwargs)
#     412         if len(extra_args):
#     413             raise TypeError('legend only accepts two non-keyword arguments')
# --> 414         self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     415         self.legend_._remove_method = self._remove_legend
#     416         return self.legend_
#
# TypeError: __init__() got an unexpected keyword argument 'lcc'

# %%
#adjust the size of the figure
fig = plt.figure(figsize=(6,6))


plt.plot(x, y, label=r'$y = \sin(x)$')
plt.plot(x, z, label=r'$y = \cos(x)$')
plt.plot(x, w, label=r'$y = \sin(4x)$')
plt.plot(x, v, label=r'$y = \cos(4x)$')

plt.xlabel(r'$x$')
plt.ylabel(r'$y(x)$')
plt.xlim([0,2*np.pi])
plt.ylim([-1.2,1.2])
plt.legend(loc=1, framealpha=0.95)


plt.gca().set_aspect(np.pi/1.2)
